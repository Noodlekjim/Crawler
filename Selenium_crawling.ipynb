# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import requests
import os

# ChromeDriver 경로 설정
chromedriver_path = os.path.join(os.getcwd(), "chromedriver.exe")
service = Service(chromedriver_path)
driver = webdriver.Chrome(service=service)

# 구글 이미지 검색 URL로 이동
query = "dogs in pirate costume"
url = f"https://www.google.com/search?q={query}&tbm=isch"
driver.get(url)

# 저장 디렉토리 설정
save_dir = "downloaded_images3"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# 스크롤 다운 반복
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# BeautifulSoup로 HTML 파싱
soup = BeautifulSoup(driver.page_source, 'html.parser')
img_tags = soup.find_all('img')

# 이미지 다운로드
for idx, img_tag in enumerate(img_tags):
    img_url = img_tag.get('src')
    
    # 데이터 URL 건너뛰기
    if img_url and img_url.startswith('data:image/'):
        continue
    
    try:
        img_data = requests.get(img_url).content
        filename = f"image_{idx}.jpg"
        filepath = os.path.join(save_dir, filename)
        with open(filepath, 'wb') as f:
            f.write(img_data)
        print(f"{filename} 다운로드 완료")
    except Exception as e:
        print(f"Error downloading {img_url}: {e}")

driver.quit()
# Out:
# Error downloading /images/branding/googlelogo/2x/googlelogo_color_92x30dp.png: Invalid URL '/images/branding/googlelogo/2x/googlelogo_color_92x30dp.png': No scheme supplied. Perhaps you meant https:///images/branding/googlelogo/2x/googlelogo_color_92x30dp.png?
# Error downloading /tia/tia.png: Invalid URL '/tia/tia.png': No scheme supplied. Perhaps you meant https:///tia/tia.png?
# Error downloading None: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Error downloading None: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Error downloading None: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Error downloading None: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Error downloading None: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Error downloading None: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# image_12.jpg 다운로드 완료
# image_13.jpg 다운로드 완료
# image_14.jpg 다운로드 완료
# image_17.jpg 다운로드 완료
# image_24.jpg 다운로드 완료
# image_67.jpg 다운로드 완료
# image_69.jpg 다운로드 완료
# image_73.jpg 다운로드 완료
# image_85.jpg 다운로드 완료
# image_169.jpg 다운로드 완료
# image_171.jpg 다운로드 완료
# image_173.jpg 다운로드 완료
# image_175.jpg 다운로드 완료
# image_177.jpg 다운로드 완료
# image_179.jpg 다운로드 완료
# image_181.jpg 다운로드 완료
# image_183.jpg 다운로드 완료
# image_185.jpg 다운로드 완료
# image_187.jpg 다운로드 완료
# image_189.jpg 다운로드 완료
# image_191.jpg 다운로드 완료
# image_193.jpg 다운로드 완료
# image_195.jpg 다운로드 완료
# image_197.jpg 다운로드 완료
# image_199.jpg 다운로드 완료
# image_201.jpg 다운로드 완료
# image_203.jpg 다운로드 완료
# image_205.jpg 다운로드 완료
# image_207.jpg 다운로드 완료
# image_209.jpg 다운로드 완료
# image_211.jpg 다운로드 완료
# image_213.jpg 다운로드 완료
# image_215.jpg 다운로드 완료
# image_217.jpg 다운로드 완료
# image_219.jpg 다운로드 완료
# image_221.jpg 다운로드 완료
# image_222.jpg 다운로드 완료
# image_223.jpg 다운로드 완료
# image_224.jpg 다운로드 완료
# image_225.jpg 다운로드 완료
# image_226.jpg 다운로드 완료
# image_227.jpg 다운로드 완료
# image_228.jpg 다운로드 완료
# image_229.jpg 다운로드 완료
# image_230.jpg 다운로드 완료
# image_231.jpg 다운로드 완료
# image_232.jpg 다운로드 완료
# image_233.jpg 다운로드 완료
# image_234.jpg 다운로드 완료
# image_235.jpg 다운로드 완료
# image_236.jpg 다운로드 완료
# image_237.jpg 다운로드 완료
# image_238.jpg 다운로드 완료
# image_239.jpg 다운로드 완료
# image_240.jpg 다운로드 완료
# image_241.jpg 다운로드 완료
# image_242.jpg 다운로드 완료
# image_243.jpg 다운로드 완료
# image_244.jpg 다운로드 완료
# image_245.jpg 다운로드 완료
# image_246.jpg 다운로드 완료
# image_247.jpg 다운로드 완료
# image_248.jpg 다운로드 완료
# image_249.jpg 다운로드 완료
# image_250.jpg 다운로드 완료
# image_251.jpg 다운로드 완료
# image_252.jpg 다운로드 완료
# image_253.jpg 다운로드 완료
# image_254.jpg 다운로드 완료
# image_255.jpg 다운로드 완료
# image_256.jpg 다운로드 완료
# image_257.jpg 다운로드 완료
# image_258.jpg 다운로드 완료
# image_259.jpg 다운로드 완료
# image_260.jpg 다운로드 완료
# image_261.jpg 다운로드 완료
# image_262.jpg 다운로드 완료
# image_263.jpg 다운로드 완료
# image_264.jpg 다운로드 완료
# image_265.jpg 다운로드 완료
# image_266.jpg 다운로드 완료
# image_267.jpg 다운로드 완료
# image_268.jpg 다운로드 완료
# image_269.jpg 다운로드 완료
# image_270.jpg 다운로드 완료
# image_271.jpg 다운로드 완료
# image_272.jpg 다운로드 완료
# image_273.jpg 다운로드 완료
# image_274.jpg 다운로드 완료
# image_275.jpg 다운로드 완료
# image_276.jpg 다운로드 완료
# image_277.jpg 다운로드 완료
# image_278.jpg 다운로드 완료
# image_279.jpg 다운로드 완료
# image_280.jpg 다운로드 완료
# image_281.jpg 다운로드 완료
# image_282.jpg 다운로드 완료
# image_283.jpg 다운로드 완료
# image_284.jpg 다운로드 완료
# image_285.jpg 다운로드 완료
# image_286.jpg 다운로드 완료
# image_287.jpg 다운로드 완료
# image_288.jpg 다운로드 완료
# image_289.jpg 다운로드 완료
# image_290.jpg 다운로드 완료
# image_291.jpg 다운로드 완료
# image_292.jpg 다운로드 완료
# image_293.jpg 다운로드 완료
# image_294.jpg 다운로드 완료
# image_295.jpg 다운로드 완료
# image_296.jpg 다운로드 완료
# image_297.jpg 다운로드 완료
# image_298.jpg 다운로드 완료
# image_299.jpg 다운로드 완료
# image_300.jpg 다운로드 완료
# image_301.jpg 다운로드 완료
# image_302.jpg 다운로드 완료
# image_303.jpg 다운로드 완료
# image_304.jpg 다운로드 완료
# image_305.jpg 다운로드 완료
# image_306.jpg 다운로드 완료
# image_307.jpg 다운로드 완료
# image_308.jpg 다운로드 완료
# image_309.jpg 다운로드 완료
# image_310.jpg 다운로드 완료
# image_311.jpg 다운로드 완료
# image_312.jpg 다운로드 완료
# image_313.jpg 다운로드 완료
# image_314.jpg 다운로드 완료
# image_315.jpg 다운로드 완료
# image_316.jpg 다운로드 완료
# image_317.jpg 다운로드 완료
# image_318.jpg 다운로드 완료
# image_319.jpg 다운로드 완료
# image_320.jpg 다운로드 완료
# image_321.jpg 다운로드 완료
# image_322.jpg 다운로드 완료
# image_323.jpg 다운로드 완료
# image_324.jpg 다운로드 완료
# image_325.jpg 다운로드 완료
# image_326.jpg 다운로드 완료
# image_327.jpg 다운로드 완료
# image_328.jpg 다운로드 완료
# image_329.jpg 다운로드 완료
# image_330.jpg 다운로드 완료
# image_331.jpg 다운로드 완료
# image_332.jpg 다운로드 완료
# image_333.jpg 다운로드 완료
# image_334.jpg 다운로드 완료
# image_335.jpg 다운로드 완료
# image_336.jpg 다운로드 완료
# image_337.jpg 다운로드 완료
# image_338.jpg 다운로드 완료
# image_339.jpg 다운로드 완료
# image_340.jpg 다운로드 완료
# image_341.jpg 다운로드 완료
# image_342.jpg 다운로드 완료
# image_343.jpg 다운로드 완료
# image_344.jpg 다운로드 완료
# image_345.jpg 다운로드 완료
# image_346.jpg 다운로드 완료
# image_347.jpg 다운로드 완료
# image_348.jpg 다운로드 완료
# image_349.jpg 다운로드 완료
# image_350.jpg 다운로드 완료
# image_351.jpg 다운로드 완료
# image_352.jpg 다운로드 완료
# image_353.jpg 다운로드 완료
# image_354.jpg 다운로드 완료
# image_355.jpg 다운로드 완료
# image_356.jpg 다운로드 완료
# image_357.jpg 다운로드 완료
# image_358.jpg 다운로드 완료
# image_359.jpg 다운로드 완료
# image_360.jpg 다운로드 완료
# image_361.jpg 다운로드 완료
# image_362.jpg 다운로드 완료
# image_363.jpg 다운로드 완료
# image_364.jpg 다운로드 완료
# image_365.jpg 다운로드 완료
# image_366.jpg 다운로드 완료
# image_367.jpg 다운로드 완료
# image_368.jpg 다운로드 완료
# image_369.jpg 다운로드 완료
# image_370.jpg 다운로드 완료
# image_371.jpg 다운로드 완료
# image_372.jpg 다운로드 완료
# image_373.jpg 다운로드 완료
# image_374.jpg 다운로드 완료
# image_375.jpg 다운로드 완료
# image_376.jpg 다운로드 완료
# image_377.jpg 다운로드 완료
# image_378.jpg 다운로드 완료
# image_379.jpg 다운로드 완료
# image_380.jpg 다운로드 완료
# image_381.jpg 다운로드 완료
# image_382.jpg 다운로드 완료
# image_383.jpg 다운로드 완료
# image_384.jpg 다운로드 완료
# image_385.jpg 다운로드 완료
# image_386.jpg 다운로드 완료
# image_387.jpg 다운로드 완료
# image_388.jpg 다운로드 완료
# image_389.jpg 다운로드 완료
# image_390.jpg 다운로드 완료
# image_391.jpg 다운로드 완료
# image_392.jpg 다운로드 완료
# image_393.jpg 다운로드 완료
# image_394.jpg 다운로드 완료
# image_395.jpg 다운로드 완료
# image_396.jpg 다운로드 완료
# image_397.jpg 다운로드 완료
# image_398.jpg 다운로드 완료
# image_399.jpg 다운로드 완료
# image_400.jpg 다운로드 완료
# image_401.jpg 다운로드 완료
# image_402.jpg 다운로드 완료
# image_403.jpg 다운로드 완료
# image_404.jpg 다운로드 완료
# image_405.jpg 다운로드 완료
# image_406.jpg 다운로드 완료
# image_407.jpg 다운로드 완료
# image_408.jpg 다운로드 완료
# image_409.jpg 다운로드 완료
# image_410.jpg 다운로드 완료
# image_411.jpg 다운로드 완료
# image_412.jpg 다운로드 완료
# image_413.jpg 다운로드 완료
# image_414.jpg 다운로드 완료
# image_415.jpg 다운로드 완료
# image_416.jpg 다운로드 완료
# image_417.jpg 다운로드 완료
# image_418.jpg 다운로드 완료
# image_419.jpg 다운로드 완료
# image_420.jpg 다운로드 완료
# image_421.jpg 다운로드 완료
# image_422.jpg 다운로드 완료
# image_423.jpg 다운로드 완료

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import csv
import time
import os

# 크롬 드라이버 경로 설정
chromedriver_path = os.path.join(os.getcwd(), "chromedriver.exe")  # 크롬 드라이버 경로를 입력해주세요.

# 크롬 드라이버 서비스 객체 생성
service = Service(chromedriver_path)

# 웹 드라이버 객체 생성
driver = webdriver.Chrome(service=service)

# 크롤링할 URL
url = 'https://www.boannews.com/media/t_list.asp?mkind=0'

# 웹 페이지 열기
driver.get(url)

# 뉴스 데이터를 저장할 리스트
news_data = []

# 크롤링할 페이지 수
num_pages = 2  # 원하는 페이지 수를 입력해주세요.

for page in range(1, num_pages + 1):
    # 현재 페이지의 HTML 소스 코드 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 뉴스 목록 찾기
    news_list = soup.select('.news_list a:not(.news_content)')

    for news in news_list:
        # 뉴스 링크 추출
        news_url = 'https://www.boannews.com' + news['href']

        # 새 탭에서 뉴스 링크 열기
        driver.execute_script("window.open('');")
        driver.switch_to.window(driver.window_handles[-1])
        driver.get(news_url)

        # 뉴스 내용 크롤링
        news_html = driver.page_source
        news_soup = BeautifulSoup(news_html, 'html.parser')

        # 뉴스 제목
        news_title = news_soup.select_one('#news_title02 h1').text.strip()

        # 뉴스 날짜
        news_date = ':'.join(news_soup.select_one('#news_util01').text.strip().split(':')[1:]).strip()

        # 뉴스 내용
        news_content = news_soup.select_one('#news_content').text.strip()

        # 크롤링한 데이터를 리스트에 추가
        news_data.append([news_title, news_date, news_content])

        # 탭 닫기
        driver.close()

        # 원래 탭으로 돌아가기
        driver.switch_to.window(driver.window_handles[0])

    # 다음 페이지로 이동
    next_page_url = f'https://www.boannews.com/media/t_list.asp?Page={page+1}&kind=0'
    driver.get(next_page_url)
    time.sleep(2)  # 2초 대기 (페이지 로딩을 위해)

# 웹 드라이버 종료
driver.quit()


# CSV 파일로 저장
with open('news_data3.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Title', 'Date', 'Content'])
    writer.writerows(news_data)

print('크롤링이 완료되었습니다.')
# Out:
# 크롤링이 완료되었습니다.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import csv
import time
import os

# 크롬 드라이버 경로 설정
chromedriver_path = os.path.join(os.getcwd(), "chromedriver.exe")  # 크롬 드라이버 경로를 입력해주세요.

# 크롬 드라이버 서비스 객체 생성
service = Service(chromedriver_path)

# 웹 드라이버 객체 생성
driver = webdriver.Chrome(service=service)

# 크롤링할 URL
url = 'https://www.boannews.com/search/news_total.asp?search=title&find=%BE%CF%C8%A3'

# 웹 페이지 열기
driver.get(url)

# 뉴스 데이터를 저장할 리스트
news_data = []

# 크롤링할 페이지 수
num_pages = 2  # 원하는 페이지 수를 입력해주세요.

for page in range(1, num_pages + 1):
    # 현재 페이지의 HTML 소스 코드 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 뉴스 목록 찾기
    news_list = soup.select('.news_list a:not(.news_content)')

    for news in news_list:
        # 뉴스 링크 추출
        news_url = 'https://www.boannews.com' + news['href']

        # 새 탭에서 뉴스 링크 열기
        driver.execute_script("window.open('');")
        driver.switch_to.window(driver.window_handles[-1])
        driver.get(news_url)

        # 뉴스 내용 크롤링
        news_html = driver.page_source
        news_soup = BeautifulSoup(news_html, 'html.parser')

        # 뉴스 제목
        news_title = news_soup.select_one('#news_title02 h1').text.strip()

        # 뉴스 날짜
        news_date = ':'.join(news_soup.select_one('#news_util01').text.strip().split(':')[1:]).strip()

        # 뉴스 내용
        news_content = news_soup.select_one('#news_content').text.strip()

        # 크롤링한 데이터를 리스트에 추가
        news_data.append([news_title, news_date, news_content])

        # 탭 닫기
        driver.close()

        # 원래 탭으로 돌아가기
        driver.switch_to.window(driver.window_handles[0])

    # 다음 페이지로 이동
    next_page_url = f'https://www.boannews.com/search/news_total.asp?Page={page+1}&search=title&find=%BE%CF%C8%A3'
    driver.get(next_page_url)
    time.sleep(2)  # 2초 대기 (페이지 로딩을 위해)

# 웹 드라이버 종료
driver.quit()


# CSV 파일로 저장
with open('news_data8.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Title', 'Date', 'Content'])
    writer.writerows(news_data)

print('크롤링이 완료되었습니다.')
# Out:
# 크롤링이 완료되었습니다.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import os
import time

# 크롬 드라이버 경로 설정
chromedriver_path = os.path.join(os.getcwd(), "chromedriver.exe")  # 크롬 드라이버 경로를 입력해주세요.

# 크롬 드라이버 서비스 객체 생성
service = Service(chromedriver_path)

# 웹 드라이버 객체 생성
driver = webdriver.Chrome(service=service)

# 블로그 URL
blog_url = 'https://creamerburger.tistory.com'

# 웹 페이지 열기
driver.get(blog_url)

# 게시물 링크 추출
post_links = driver.find_elements(By.CSS_SELECTOR, '.list_content .link_post')

# 댓글을 단 링크 목록
commented_links = []

for link in post_links:
    post_url = link.get_attribute('href')
    
    # 새 탭에서 게시물 링크 열기
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[-1])
    driver.get(post_url)
    
    # 댓글 작성 필드 찾기
    name_input = driver.find_element(By.CSS_SELECTOR, 'input[placeholder="이름"]')
    password_input = driver.find_element(By.CSS_SELECTOR, 'input[placeholder="비밀번호"]')
    comment_textarea = driver.find_element(By.CSS_SELECTOR, 'textarea[placeholder="댓글을 달아주세요 :)"]')
    submit_button = driver.find_element(By.CSS_SELECTOR, '.commentWrite input[type="submit"]')
    
    # 댓글 작성
    name_input.send_keys("ㅈㅅ")
    password_input.send_keys("1234")
    comment_textarea.send_keys("좋아요!")
    submit_button.click()
    
    time.sleep(2)  # 댓글 작성 후 잠시 대기
    
    # 댓글을 단 링크 목록에 추가
    commented_links.append(post_url)
    
    # 탭 닫기
    driver.close()
    
    # 원래 탭으로 돌아가기
    driver.switch_to.window(driver.window_handles[0])

# 웹 드라이버 종료
driver.quit()

# 댓글을 단 링크 목록 출력
print("댓글을 단 링크 목록:")
for link in commented_links:
    print(link)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[5], line 44
#      42 # 댓글 작성
#      43 name_input.send_keys("ㅈㅅ")
# ---> 44 password_input.send_keys("1234")
#      45 comment_textarea.send_keys("좋아요!")
#      46 submit_button.click()
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webelement.py:231, in WebElement.send_keys(self, *value)
#     228             remote_files.append(self._upload(file))
#     229         value = "\n".join(remote_files)
# --> 231 self._execute(
#     232     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     233 )
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=125.0.6422.61)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6524522C2+60002]
# 	(No symbol) [0x00007FF6523CCA59]
# 	(No symbol) [0x00007FF652287EDA]
# 	(No symbol) [0x00007FF65225D5B5]
# 	(No symbol) [0x00007FF652303727]
# 	(No symbol) [0x00007FF65231B3A1]
# 	(No symbol) [0x00007FF6522FC033]
# 	(No symbol) [0x00007FF6522C9657]
# 	(No symbol) [0x00007FF6522CA251]
# 	GetHandleVerifier [0x00007FF652763E2D+3278285]
# 	GetHandleVerifier [0x00007FF6527B0190+3590448]
# 	GetHandleVerifier [0x00007FF6527A61D0+3549552]
# 	GetHandleVerifier [0x00007FF652501DE6+779654]
# 	(No symbol) [0x00007FF6523D7ACF]
# 	(No symbol) [0x00007FF6523D2EE4]
# 	(No symbol) [0x00007FF6523D3072]
# 	(No symbol) [0x00007FF6523C2C4F]
# 	BaseThreadInitThunk [0x00007FFD62BC257D+29]
# 	RtlUserThreadStart [0x00007FFD6362AA58+40]
